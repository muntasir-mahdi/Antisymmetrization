# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('ETONew.csv')

# %%
df.head(10)
# Out:
#                Field Resistance            Field.1 Resistance.1  \
# 0                 Oe        Ohm                 Oe          Ohm
# 1                NaN        10K                NaN          50K
# 2  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 3   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 4  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 5   -10000.123046875   3301.445     -10000.2890625     4201.712
# 6   -9000.3486328125   3301.919   -9000.2607421875     4208.062
# 7       -9000.359375   3301.812    -9000.205078125     4206.279
# 8   -9000.4033203125   3301.913    -9000.216796875     4203.366
# 9    -9000.392578125    3301.29     -9000.23828125     4201.368
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0                 Oe          Ohm                 Oe          Ohm
# 1                NaN         100K                NaN         150K
# ...

# %%
df.drop(['Field.13','Resistance.12', 'Resistance.13', 'Field.12'], axis =1, inplace= True)

# %%
df.fillna(0)
# Out:
#                  Field Resistance            Field.1 Resistance.1  \
# 0                   Oe        Ohm                 Oe          Ohm
# 1                    0        10K                  0          50K
# 2    -10000.1337890625   3301.331    -10000.27734375     4215.815
# 3     -10000.189453125   3301.218  -10000.3212890625     4203.088
# 4    -10000.1337890625   3301.377  -10000.3212890625     4197.347
# ..                 ...        ...                ...          ...
# 165   -9000.1396484375    3302.95   -9000.2822265625     4240.766
# 166    -10000.33203125   3302.051     -9999.98046875     4242.414
# 167  -10000.3212890625    3302.05   -9999.9912109375     4246.745
# 168  -10000.2998046875   3302.277  -10000.0126953125      4247.96
# 169   -10000.310546875   3302.183   -10000.001953125     4246.835
#
#                Field.2 Resistance.2            Field.3 Resistance.3  \
# 0                   Oe          Ohm                 Oe          Ohm
# ...

# %%
df.head(10)
# Out:
#                Field Resistance            Field.1 Resistance.1  \
# 0                 Oe        Ohm                 Oe          Ohm
# 1                NaN        10K                NaN          50K
# 2  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 3   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 4  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 5   -10000.123046875   3301.445     -10000.2890625     4201.712
# 6   -9000.3486328125   3301.919   -9000.2607421875     4208.062
# 7       -9000.359375   3301.812    -9000.205078125     4206.279
# 8   -9000.4033203125   3301.913    -9000.216796875     4203.366
# 9    -9000.392578125    3301.29     -9000.23828125     4201.368
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0                 Oe          Ohm                 Oe          Ohm
# 1                NaN         100K                NaN         150K
# ...

# %%
df = df.dropna()

# %%
df.head(5)
# Out:
#                Field Resistance            Field.1 Resistance.1  \
# 0                 Oe        Ohm                 Oe          Ohm
# 2  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 3   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 4  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 5   -10000.123046875   3301.445     -10000.2890625     4201.712
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0                 Oe          Ohm                 Oe          Ohm
# 2  -10000.0126953125     4177.697  -10000.2998046875     256.8307
# 3   -9999.9912109375     4199.244  -10000.2998046875     271.1156
# 4  -10000.0244140625     4235.337   -10000.310546875     257.6828
# 5   -10000.001953125     4214.067       -10000.34375     265.4473
#
#             Field.4 Resistance.4  ...            Field.7 Resistance.7  \
# 0                Oe          Ohm  ...                 Oe          Ohm
# ...

# %%
df = df.drop([0]).reset_index()

# %%
df.head(5)
# Out:
#    index              Field Resistance            Field.1 Resistance.1  \
# 0      1  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 1      2   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 2      3  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 3      4   -10000.123046875   3301.445     -10000.2890625     4201.712
# 4      5   -9000.3486328125   3301.919   -9000.2607421875     4208.062
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0  -10000.0126953125     4177.697  -10000.2998046875     256.8307
# 1   -9999.9912109375     4199.244  -10000.2998046875     271.1156
# 2  -10000.0244140625     4235.337   -10000.310546875     257.6828
# 3   -10000.001953125     4214.067       -10000.34375     265.4473
# 4   -9000.2607421875     4197.163   -9000.2607421875     316.0423
#
#             Field.4  ...            Field.7 Resistance.7            Field.8  \
# ...

# %%
df.drop('index', axis =1, inplace= True)

# %%
df.head(10)
# Out:
#                Field Resistance            Field.1 Resistance.1  \
# 0  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 1   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 2  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 3   -10000.123046875   3301.445     -10000.2890625     4201.712
# 4   -9000.3486328125   3301.919   -9000.2607421875     4208.062
# 5       -9000.359375   3301.812    -9000.205078125     4206.279
# 6   -9000.4033203125   3301.913    -9000.216796875     4203.366
# 7    -9000.392578125    3301.29     -9000.23828125     4201.368
# 8    -8000.353515625   3301.772    -8000.353515625     4211.115
# 9  -8000.33154296875   3301.565    -8000.365234375     4213.251
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0  -10000.0126953125     4177.697  -10000.2998046875     256.8307
# 1   -9999.9912109375     4199.244  -10000.2998046875     271.1156
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Field          168 non-null    object
#  1   Resistance     169 non-null    object
#  2   Field.1        168 non-null    object
#  3   Resistance.1   169 non-null    object
#  4   Field.2        168 non-null    object
#  5   Resistance.2   169 non-null    object
#  6   Field.3        168 non-null    object
#  7   Resistance.3   169 non-null    object
#  8   Field.4        168 non-null    object
#  9   Resistance.4   169 non-null    object
#  10  Field.5        168 non-null    object
#  11  Resistance.5   169 non-null    object
#  12  Field.6        168 non-null    object
#  13  Resistance.6   169 non-null    object
#  14  Field.7        40 non-null     object
#  15  Resistance.7   41 non-null     object
#  16  Field.8        168 non-null    object
# ...

# %%
df = df.astype(float)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-5f5efa3b8ed4> in <module>
# ----> 1 df = df.astype(float)
#       2 df.info()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
rahe = (df.max()-df.min())/2

# %%
R_AHE= rahe.to_frame()

# %%
R_AHE
# Out:
#                         0
# Field         7499.894535
# Resistance       0.192555
# Field.1       7499.976805
# Resistance.1     0.203100
# Field.2       7499.900150
# Resistance.2     0.395464
# Field.3       9999.969238
# Resistance.3     0.078381
# Field.4       9500.203125
# Resistance.4     0.017680
# Field.5       7000.254885
# Resistance.5     0.004245
# Field.6       8500.059325
# Resistance.6     0.000589
# Field.7       7499.900150
# Resistance.7     0.128735
# Field.8       9999.969238
# Resistance.8     0.102578

# %%
R_AHE.to_csv('S118_Rahe.csv')
