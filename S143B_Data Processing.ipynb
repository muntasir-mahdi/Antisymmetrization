# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df = pd.read_csv('S143B_Raw.csv')

# %%
df.head()
# Out:
#           Field  Resistance
# 0 -30000.314453   -88.37360
# 1 -30000.314453   -88.37281
# 2 -30000.292969   -88.37300
# 3 -30000.238281   -88.37225
# 4 -28000.281250   -88.38554

# %%
df[['Field']]
# Out:
#             Field
# 0   -30000.314453
# 1   -30000.314453
# 2   -30000.292969
# 3   -30000.238281
# 4   -28000.281250
# ..            ...
# 243 -28000.158203
# 244 -30000.205078
# 245 -30000.205078
# 246 -30000.150391
# 247 -30000.216797
#
# [248 rows x 1 columns]

# %%
df.iloc[0:2,:]
# Out:
#   Field Resistance Field.1 Resistance.1 Field.2 Resistance.2 Field.3  \
# 0    Oe        Ohm      Oe          Ohm      Oe          Ohm      Oe
# 1   NaN        10K     NaN          50K     NaN         100K     NaN
#
#   Resistance.3 Field.4 Resistance.4  ... Field.7 Resistance.7 Field.8  \
# 0          Ohm      Oe          Ohm  ...      Oe          Ohm      Oe
# 1         150K     NaN         170K  ...     NaN         230K     NaN
#
#   Resistance.8 Field.9 Resistance.9 Field.10 Resistance.10 Field.11  \
# 0          Ohm      Oe          Ohm       Oe           Ohm       Oe
# 1         250K     NaN         260K      NaN          270K      NaN
#
#   Resistance.11
# 0           Ohm
# 1          280K
#
# [2 rows x 24 columns]

# %%
df = df.drop([0,1]).reset_index()

# %%
df.head()
# Out:
#    index              Field Resistance            Field.1 Resistance.1  \
# 0      2  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 1      3   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 2      4  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 3      5   -10000.123046875   3301.445     -10000.2890625     4201.712
# 4      6   -9000.3486328125   3301.919   -9000.2607421875     4208.062
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0  -10000.0126953125     4177.697  -10000.2998046875     256.8307
# 1   -9999.9912109375     4199.244  -10000.2998046875     271.1156
# 2  -10000.0244140625     4235.337   -10000.310546875     257.6828
# 3   -10000.001953125     4214.067       -10000.34375     265.4473
# 4   -9000.2607421875     4197.163   -9000.2607421875     316.0423
#
#             Field.4  ...            Field.7 Resistance.7            Field.8  \
# ...

# %%
df.drop('index', axis =1, inplace= True)

# %%
df
# Out:
#                  Field Resistance            Field.1 Resistance.1  \
# 0    -10000.1337890625   3301.331    -10000.27734375     4215.815
# 1     -10000.189453125   3301.218  -10000.3212890625     4203.088
# 2    -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 3     -10000.123046875   3301.445     -10000.2890625     4201.712
# 4     -9000.3486328125   3301.919   -9000.2607421875     4208.062
# ..                 ...        ...                ...          ...
# 163   -9000.1396484375    3302.95   -9000.2822265625     4240.766
# 164    -10000.33203125   3302.051     -9999.98046875     4242.414
# 165  -10000.3212890625    3302.05   -9999.9912109375     4246.745
# 166  -10000.2998046875   3302.277  -10000.0126953125      4247.96
# 167   -10000.310546875   3302.183   -10000.001953125     4246.835
#
#                Field.2 Resistance.2            Field.3 Resistance.3  \
# 0    -10000.0126953125     4177.697  -10000.2998046875     256.8307
# ...

# %%
df.loc[0:3]
# Out:
#                Field Resistance            Field.1 Resistance.1  \
# 0  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 1   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 2  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 3   -10000.123046875   3301.445     -10000.2890625     4201.712
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0  -10000.0126953125     4177.697  -10000.2998046875     256.8307
# 1   -9999.9912109375     4199.244  -10000.2998046875     271.1156
# 2  -10000.0244140625     4235.337   -10000.310546875     257.6828
# 3   -10000.001953125     4214.067       -10000.34375     265.4473
#
#             Field.4 Resistance.4  ...            Field.7 Resistance.7  \
# 0  170.171752929688     920.3052  ...    -10000.22265625     31116.59
# 1  170.163925170898     852.9095  ...  -10000.2333984375     29977.07
# 2  170.156616210938     1026.709  ...   -10000.244140625     20090.52
# ...

# %%
dftest = df.rolling(min_periods=5).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4760/437195929.py in <module>
# ----> 1 dftest = df.rolling(min_periods=5).mean()
#
# TypeError: rolling() missing 1 required positional argument: 'window'

# %%
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=4)
dftest = df.rolling(window=indexer, min_periods=1).mean()

# %%
dftest.head(10)
# Out:
#           Field  Resistance       Field.1  Resistance.1       Field.2  \
# 0 -10000.145020  3301.34275 -10000.302246    4204.49050 -10000.007568
# 1  -9750.198730  3301.48975  -9750.298096    4202.55225  -9750.069580
# 2  -9500.241211  3301.63825  -9500.269043    4203.35000  -9500.131348
# 3  -9250.308594  3301.77225  -9250.242920    4204.85475  -9250.187744
# 4  -9000.375977  3301.73350  -9000.230225    4204.76875  -9000.244141
# 5  -8750.377197  3301.69675  -8750.253418    4205.53200  -8750.267334
# 6  -8500.370239  3301.63500  -8500.293457    4207.27500  -8500.301758
# 7  -8250.360718  3301.64875  -8250.330566    4209.74725  -8250.336060
# 8  -8000.342773  3301.79400  -8000.351196    4212.39275  -8000.362061
# 9  -7750.327759  3301.88075  -7750.305908    4213.26300  -7750.347046
#
#    Resistance.2       Field.3  Resistance.3     Field.4  Resistance.4  ...  \
# 0    4206.58625 -10000.313477    262.769100  170.161724    945.832450  ...
# ...

# %%
df.head(10)
# Out:
#                Field Resistance            Field.1 Resistance.1  \
# 0  -10000.1337890625   3301.331    -10000.27734375     4215.815
# 1   -10000.189453125   3301.218  -10000.3212890625     4203.088
# 2  -10000.1337890625   3301.377  -10000.3212890625     4197.347
# 3   -10000.123046875   3301.445     -10000.2890625     4201.712
# 4   -9000.3486328125   3301.919   -9000.2607421875     4208.062
# 5       -9000.359375   3301.812    -9000.205078125     4206.279
# 6   -9000.4033203125   3301.913    -9000.216796875     4203.366
# 7    -9000.392578125    3301.29     -9000.23828125     4201.368
# 8    -8000.353515625   3301.772    -8000.353515625     4211.115
# 9  -8000.33154296875   3301.565    -8000.365234375     4213.251
#
#              Field.2 Resistance.2            Field.3 Resistance.3  \
# 0  -10000.0126953125     4177.697  -10000.2998046875     256.8307
# 1   -9999.9912109375     4199.244  -10000.2998046875     271.1156
# ...

# %%
df_avgd = dftest

# %% [markdown]
# df_avgd = df.groupby()

# %% [markdown]
# df.iloc[:5]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Field          168 non-null    object
#  1   Resistance     168 non-null    object
#  2   Field.1        168 non-null    object
#  3   Resistance.1   168 non-null    object
#  4   Field.2        168 non-null    object
#  5   Resistance.2   168 non-null    object
#  6   Field.3        168 non-null    object
#  7   Resistance.3   164 non-null    object
#  8   Field.4        168 non-null    object
#  9   Resistance.4   167 non-null    object
#  10  Field.5        168 non-null    object
#  11  Resistance.5   168 non-null    object
#  12  Field.6        168 non-null    object
#  13  Resistance.6   161 non-null    object
#  14  Field.7        40 non-null     object
#  15  Resistance.7   40 non-null     object
#  16  Field.8        168 non-null    object
# ...

# %%
df = df.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Field          168 non-null    float64
#  1   Resistance     168 non-null    float64
#  2   Field.1        168 non-null    float64
#  3   Resistance.1   168 non-null    float64
#  4   Field.2        168 non-null    float64
#  5   Resistance.2   168 non-null    float64
#  6   Field.3        168 non-null    float64
#  7   Resistance.3   164 non-null    float64
#  8   Field.4        168 non-null    float64
#  9   Resistance.4   167 non-null    float64
#  10  Field.5        168 non-null    float64
#  11  Resistance.5   168 non-null    float64
#  12  Field.6        168 non-null    float64
#  13  Resistance.6   161 non-null    float64
#  14  Field.7        40 non-null     float64
#  15  Resistance.7   40 non-null     float64
#  16  Field.8        168 non-null    float64
# ...

# %%
dftest = df.iloc[:3].mean(axis=0)

# %%
dftest
# Out:
# Field          -10000.176367
# resistence        -11.420672
# Field.1        -10000.363086
# resistence.1      -11.331966
# Field.2         -9999.887695
# resistence.2      -11.214444
# Field.3         -9999.991211
# resistence.3      -11.064922
# Field.4        -10000.325586
# resistence.4      -10.896764
# Field.5        -10000.208984
# resistence.5      -10.747154
# Field.6         -9999.951172
# resistence.6      -10.075326
# Field.7         -9999.874414
# resistence.7       -9.698345
# Field.8         -9999.867969
# resistence.8       -9.669990
# Field.9         -9999.773242
# resistence.9       -9.735624
# dtype: float64

# %%
for row in df.iterrows():
    df.loc[row:row+4].mean(axis=0).to_frame()
    row = row+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4760/3515615874.py in <module>
#       1 for row in df.iterrows():
# ----> 2     df.loc[row:row+4].mean(axis=0).to_frame()
#       3     row = row+5
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
df2= df.loc[0:3].mean(axis=0)

# %%
df2= df2.to_frame()

# %%
df2.T
# Out:
#           Field  resistence       Field.1  resistence.1      Field.2  \
# 0 -10000.176367  -11.420672 -10000.363086    -11.331966 -9999.887695
#
#    resistence.2      Field.3  resistence.3       Field.4  resistence.4  \
# 0    -11.214444 -9999.991211    -11.064922 -10000.325586    -10.896764
#
#         Field.5  resistence.5      Field.6  resistence.6      Field.7  \
# 0 -10000.208984    -10.747154 -9999.951172    -10.075326 -9999.874414
#
#    resistence.7      Field.8  resistence.8      Field.9  resistence.9
# 0     -9.698345 -9999.867969      -9.66999 -9999.773242     -9.735624

# %%
for row in df.iterrows():
    df2 = df.loc[:3].mean().to_frame().T

# %%
df.loc[0:3].mean(axis=0).to_frame().T
# Out:
#           Field  resistence       Field.1  resistence.1      Field.2  \
# 0 -10000.176367  -11.420672 -10000.363086    -11.331966 -9999.887695
#
#    resistence.2      Field.3  resistence.3       Field.4  resistence.4  \
# 0    -11.214444 -9999.991211    -11.064922 -10000.325586    -10.896764
#
#         Field.5  resistence.5      Field.6  resistence.6      Field.7  \
# 0 -10000.208984    -10.747154 -9999.951172    -10.075326 -9999.874414
#
#    resistence.7      Field.8  resistence.8      Field.9  resistence.9
# 0     -9.698345 -9999.867969      -9.66999 -9999.773242     -9.735624

# %%
df2 = df.groupby(np.arange(len(df)) // 4).mean()

# %%
df2
# Out:
#            Field  Resistance       Field.1  Resistance.1       Field.2  \
# 0  -10000.145020  3301.34275 -10000.302246    4204.49050 -10000.007568
# 1   -9000.375977  3301.73350  -9000.230225    4204.76875  -9000.244141
# 2   -8000.342773  3301.79400  -8000.351196    4212.39275  -8000.362061
# 3   -7000.279541  3301.85100  -7000.144409    4217.26375  -7000.279419
# 4   -6000.334351  3301.97550  -6000.210449    4217.05900  -6000.196533
# 5   -5000.248657  3302.16400  -5000.138672    4226.04750  -5000.394531
# 6   -4000.229248  3302.27050  -4000.262268    4227.76125  -4000.201660
# 7   -3000.259216  3302.52875  -3000.132751    4228.93825  -3000.256531
# 8   -2000.358154  3302.91700  -2000.074646    4229.60075  -2000.008636
# 9   -1000.355148  3303.02600  -1000.225845    4235.38925  -1000.190063
# 10     -0.126572  3303.49025     -0.277908    4232.74775     -0.236634
# 11   1000.146027  3304.06100   1000.008484    4230.92125   1000.038712
# ...

# %%
df2.to_csv('S117New_Processed.csv')
